# %%
import os
print(os.environ['PATH'])
# Out:
# /Users/Sarthak/anaconda/bin:/Library/Frameworks/Python.framework/Versions/3.5/bin:/Library/Frameworks/Python.framework/Versions/3.5/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/TeX/texbin

# %%
from sklearn import tree
import pandas
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import graphviz 
from sklearn import metrics

# %%
file_name = 'train.csv'

# %%
data = pandas.read_csv(file_name, index_col='PassengerId' )

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.dropna(inplace=True)

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.drop(['Name','Ticket', 'Cabin'],axis = 1,inplace = True)

# %%
data['Embarked'] = LabelEncoder().fit_transform(data['Embarked'])
data['Sex'] = LabelEncoder().fit_transform(data['Sex'])

# %%
train_x,test_x, train_y,test_y = train_test_split(data.drop('Survived', axis = 1), data['Survived'], test_size = 0.33)

# %%
clf1 = tree.DecisionTreeClassifier(max_depth=1)

# %%
clf1 = clf1.fit( train_x,train_y )

# %%
pridict_d_1 = clf1.predict(test_x)

# %%
print(metrics.accuracy_score(test_y, pridict_d_1))
# Out:
# 0.754098360656

# %%
dot_data = tree.export_graphviz(clf1,feature_names=data.columns,filled=True, rounded=True,  special_characters=True,out_file=None) 
graph = graphviz.Source(dot_data) 
graph

# %%
clf2 = tree.DecisionTreeClassifier(max_depth=2)
clf2 = clf2.fit( train_x,train_y )
pridict_d_1 = clf2.predict(test_x)
print(metrics.accuracy_score(test_y, pridict_d_1))
# Out:
# 0.819672131148

# %%
dot_data = tree.export_graphviz(clf2,feature_names=data.columns,filled=True, rounded=True,  special_characters=True,out_file=None) 
graph = graphviz.Source(dot_data) 
graph

# %%
clf3 = tree.DecisionTreeClassifier(max_depth=3)
clf3 = clf3.fit( train_x,train_y )
pridict_d_1 = clf3.predict(test_x)
print(metrics.accuracy_score(test_y, pridict_d_1))
# Out:
# 0.786885245902

# %%
dot_data = tree.export_graphviz(clf3,feature_names=data.columns,filled=True, rounded=True,  special_characters=True,out_file=None) 
graph = graphviz.Source(dot_data) 
graph

# %%
clf4 = tree.DecisionTreeClassifier(max_depth=4)
clf4 = clf4.fit( train_x,train_y )
pridict_d_1 = clf3.predict(test_x)
print(metrics.accuracy_score(test_y, pridict_d_1))
# Out:
# 0.786885245902

# %%
clf5 = tree.DecisionTreeClassifier(max_depth=5)
clf5 = clf5.fit( train_x,train_y )
pridict_d_1 = clf.predict(test_x)
print(metrics.accuracy_score(test_y, pridict_d_1))
# Out:
# 0.754098360656

# %%
clf6 = tree.DecisionTreeClassifier(max_depth=6)
clf6 = clf6.fit( train_x,train_y )
pridict_d_1 = clf6.predict(test_x)
print(metrics.accuracy_score(test_y, pridict_d_1))
# Out:
# 0.704918032787
